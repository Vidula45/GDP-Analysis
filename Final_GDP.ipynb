# %% [markdown]
# # Part-I: GDP Analysis of the Indian States

# %% [markdown]
# ## Part1-A:

# %%
#importing all the required libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# %%
#Reading the Data-1A:
data=pd.read_csv(r'..\Final_GDP\ab40c054-5031-4376-b52e-9813e776f65e.csv')
data.head()
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15         526468.0
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
# 3            16761.0  198098.0  373920.0      234982.0  40633.0  895027.0
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana  ...  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 0  297539.0  ...   359433.0  19208.0       724049.0     115523.0
# ...

# %%
#Handling data:
data=data.drop('West Bengal1',axis=1) #West Bengal contains all missing values, hence dropping the column
#We need only the States from DATA-1A, hence dropping the Union Territories
data=data.drop('Andaman & Nicobar Islands',axis=1)
data=data.drop('Chandigarh',axis=1)
data=data.drop('Delhi',axis=1)
data=data.drop('Puducherry',axis=1)
data=data.drop('Jammu & Kashmir',axis=1)
data
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %% [markdown]
# ###  Plot a graph for rows " % Growth over previous year" for all the states (not union territories) whose data is available, use as much data as possible for this exercise. Use the best fit line to represent the growth for each state. Draw a similar line graph for the nation as well.

# %%
#Extracting only the (% Growth over previous year) rows from the 'data' dataframe.
percent_growth = data[data['Items  Description'] == '(% Growth over previous year)'] 
percent_growth = percent_growth.drop('Items  Description', axis = 1)

# %%
#Plotting a REGPLOT for (% Growth over previous year" ) for all the states:
plt.rcParams.update({'figure.max_open_warning': 0})
#using reg plot:
fig=plt.figure(figsize=(20,15))
x=[1,2,3,4,5]
for i in range(1, len(percent_growth.columns)-1):
    
    plt.subplot(7,4,i)
    sns.regplot(x=x, y=percent_growth.columns[i], data=percent_growth)
    
plt.show()

# %%
#Plotting a Regplot for Nation  : 
sns.regplot(x=x, y=percent_growth['All_India GDP'], data=percent_growth)
plt.title('Growth Rate of Nation')
# Out:
# Text(0.5, 1.0, 'Growth Rate of Nation')

# %% [markdown]
# #### Q.How will you compare the growth rates of any two states?

# %%
percent_growth.mean(axis=0)
# Out:
# Andhra Pradesh       13.036000
# Arunachal Pradesh    14.162500
# Assam                11.877500
# Bihar                13.765000
# Chhattisgarh         12.934000
# Goa                   2.020000
# Gujarat              12.767500
# Haryana              12.998000
# Himachal Pradesh     12.816667
# Jharkhand            12.567500
# Karnataka            14.230000
# Kerala               12.752500
# Madhya Pradesh       15.266000
# Maharashtra          12.103333
# Manipur              11.890000
# Meghalaya             8.244000
# Mizoram              16.866667
# Nagaland             15.953333
# Odisha               10.740000
# Punjab               11.346667
# Rajasthan            11.940000
# Sikkim               10.492500
# Tamil Nadu           12.250000
# Telangana            12.732000
# Tripura              15.613333
# Uttar Pradesh        12.367500
# Uttarakhand          12.382500
# All_India GDP        11.798000
# dtype: float64

# %%
fig=plt.figure(figsize=(10,8))
percent_growth.mean(axis=0,).sort_values(ascending=False).plot(kind='bar',color='c') 
plt.title('Average growth rate of all States')
plt.show()

# %% [markdown]
# ANSWER: Growth rate can be determined by calculating the average of the growth percentage.
# From the above bar chart, we can compare the average of any 2 States.
# If we compare growth rates of Maharashtra and Goa, the growth rate of Goa is less than that of Maharashtra.
# Gujarat and Haryana has same growth rate.
# Growth rate of Mizoram is much greater than Goa.

# %% [markdown]
# #### Q.Which states have been growing consistently fast, and which ones have been struggling? Rank top 3 fastest and 3 slowest-growing states.

# %% [markdown]
# ANSWER:
# From the above bar graph we can conclude that,
# Top 3 Fastest growing states: MIZORAM, NAGALAND, TRIPURA
# Top 3 Slowest growing states : GOA, MEGHALAYA ,SIKKIM

# %% [markdown]
# #### Q.What is the Nation's growth rate?

# %%
x=[1,2,3,4,5]
sns.regplot(x=x, y=percent_growth['All_India GDP'], data=percent_growth)
plt.title('Growth Rate of Nation')
plt.show()
percent_growth['All_India GDP'].mean()
# Out:
# 11.797999999999998

# %% [markdown]
# #### Q.What has been the growth rate of your home state, and how does it compare to the national growth rate?

# %%
fig=plt.figure(figsize=(6.5, 4.8))
x=[1,2,3,4,5]
plt.subplot(1,2,1)
sns.regplot(x=x, y=percent_growth['Maharashtra'], data=percent_growth)
percent_growth['Maharashtra'].mean()#average growth of Maharastra.
percent_growth['All_India GDP'].mean() #average growth of Nation.
plt.subplot(1,2,2)
percent_growth[['All_India GDP','Maharashtra']].mean().plot(kind='bar',color='g')
plt.xlabel('COMPARISON')
plt.ylabel('Growth Rate')
plt.show()

# %% [markdown]
# ### Plot the total GDP of the states for the year 2015-16:

# %%
#Extracting only the (GSDP - CURRENT PRICES (` in Crore)) rows from the 'data' dataframe.
percent_gdp= data[data['Items  Description'] == 'GSDP - CURRENT PRICES (` in Crore)'] 
#extracting the data for the year 2015-16.
percent_gdp=percent_gdp[percent_gdp['Duration']=='2015-16']
#extracting only the states columns.
percent_gdp=percent_gdp.iloc[:,2:-1] 
#transposing the data
percent_gdp=percent_gdp.T 
percent_gdp=percent_gdp.iloc[:,-1]
#Sorting the gdp values in Descending order
percent_gdp=percent_gdp.sort_values(ascending=False)
percent_gdp
# Out:
# Tamil Nadu           1212668.0
# Uttar Pradesh        1153795.0
# Karnataka            1027068.0
# Gujarat               994316.0
# Andhra Pradesh        609934.0
# Kerala                588337.0
# Telangana             575631.0
# Madhya Pradesh        543975.0
# Haryana               485184.0
# Bihar                 413503.0
# Odisha                341887.0
# Chhattisgarh          260776.0
# Jharkhand             241955.0
# Assam                 224234.0
# Uttarakhand           184091.0
# Goa                    45002.0
# Meghalaya              26745.0
# Arunachal Pradesh      18784.0
# Sikkim                 16637.0
# Himachal Pradesh           NaN
# Maharashtra                NaN
# Manipur                    NaN
# Mizoram                    NaN
# Nagaland                   NaN
# Punjab                     NaN
# Rajasthan                  NaN
# Tripura                    NaN
# Name: 4, dtype: float64

# %%
#Plotting a bar graph for the total GDP:
fig=plt.figure(figsize=(10,10))
percent_gdp.plot(kind='bar',color='g')
plt.xlabel('States')
plt.ylabel('Total GDP')
plt.title('Total GDP across all states')
plt.show()

# %% [markdown]
# #### Q.Which Plot will you use for this? Why? (Remeber to plot the graph in a way such as it is easier to read and compare)

# %% [markdown]
# ##### ANSWER:
# I used Bar Chart for plotting the total GDP across all the states. Bar Charts are used when there is a categorical data and a numeric data.
# We have 'States' as a Categorical data and 'Total GDP' as a Numeric data.

# %% [markdown]
# #### Q. Identify the top 5 and the bottom 5 states based on total GDP.

# %% [markdown]
# ##### ANSWER:
# ###### TOP 5 states based on total GDP are :
# ###### Tamilnadu, Uttarpradesh, Karnataka, Gujrat, Andhrapradesh.
# ###### BOTTOM 5 states based on total GDP are :(excluding the states with NAN values.)
# ###### Sikkim, Arunachal Pradesh, Meghalaya, Goa, Uttarakhand

# %% [markdown]
# #### Q.What insights can you draw from this graph? What states are performing poorly? (Remember: this will not be solely based on total GDP)

# %% [markdown]
# ##### ANSWER:
# The states that are poorly performing are Sikkim , Arunachal Pradesh , Goa. We can conclude that these states must rereduce the cost of borrowing and increase consumer spending and investment.

# %% [markdown]
# ## Part1-B:

# %% [markdown]
# ### For the analysis below, use Data I-B. You can also use Data I-B along with Data I-A if required. Also, perform the analysis only for the duration 2014-15.

# %%
#Reading DATA-1B :
#creating a pathh for all the files.
path=r'..\Final_GDP\states_ut'

# %%
#all the files are added into 'all_files'
all_files=glob.glob(path+'\*.csv')
all_files
# Out:
# ['..\\Final_GDP\\states_ut\\NAD-Andhra_Pradesh-GSVA_cur_2016-17.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Arunachal_Pradesh-GSVA_cur_2015-16.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Assam-GSVA_cur_2015-16.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Bihar-GSVA_cur_2015-16.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Chandigarh-GSVA_cur_2015-16.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Chhattisgarh-GSVA_cur_2016-17.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Delhi-GSVA_cur_2016-17.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Goa-GSVA_cur_2015-16.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Gujarat-GSVA_cur_2015-16.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Haryana-GSVA_cur_2016-17.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Himachal_Pradesh-GSVA_cur_2014-15.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Jharkhand-GSVA_cur_2015-16.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Karnataka-GSVA_cur_2015-16.csv',
#  '..\\Final_GDP\\states_ut\\NAD-Kerala-GSVA_cur_2015-16.csv',
# ...

# %%
#Creating a dataframe from the all the files for each State and Union Territories.
list1=[]
for location in all_files:
    df=pd.read_csv(location,encoding = 'unicode_escape')
    df=df[['S.No.','Item','2014-15']]
    df=df.T
    df.columns=df.iloc[1]
    df=df[2:]
    df['State']=location.split('\\')[-1].split('.')[0].split('-')[1] #Creating a new column named 'STATE'. 
    df.head()
    list1.append(df) #adding all values to 'list1'

# %%
#concating all the data from a list
df_new=pd.concat(list1,axis=0,ignore_index=True,sort=False)
df_new
# Out:
#    Agriculture, forestry and fishing        Crops    Livestock  \
# 0                           14819416      7893514      4309078
# 1                             686117       415520        38387
# 2                            3855548      2890544       173478
# 3                            7951890      4688237      2060296
# 4                              16233         1659        13992
# 5                            3948847      2613371       352208
# 6                             250568        64959       183770
# 7                             308507       140421        30141
# 8                          1.377e+07  9.67109e+06  2.69891e+06
# 9                        8.01524e+06  4.63673e+06  2.91617e+06
# 10                           1514981       853758       110304
# 11                           3211065      2094466       562503
# 12                          11219422      8157179      1868771
# 13                           5930617      3070386      1656104
# ...

# %%
#Dropping all the sub-sub sectors as we need to deal only with Sectors and Sub-sectors.
df_new=df_new.drop('Crops',axis=1)
df_new=df_new.drop('Livestock',axis=1)
df_new=df_new.drop('Forestry and logging',axis=1)
df_new=df_new.drop('Fishing and aquaculture',axis=1)
df_new=df_new.drop('Trade & repair services',axis=1)
df_new=df_new.drop('Hotels & restaurants',axis=1)
df_new=df_new.drop('Railways',axis=1)
df_new=df_new.drop('Road transport',axis=1)
df_new=df_new.drop('Water transport',axis=1)
df_new=df_new.drop('Air transport',axis=1)
df_new=df_new.drop('Services incidental to transport',axis=1)
df_new=df_new.drop('Storage',axis=1)
df_new=df_new.drop('Communication & services related to broadcasting',axis=1)
df_new=df_new.drop('Services incidental to transport*',axis=1)
df_new=df_new.drop('Trade & repair services*',axis=1)
df_new=df_new.drop('Road transport**',axis=1)
df_new=df_new.drop('Road transport*',axis=1)

df_new
# Out:
#    Agriculture, forestry and fishing Mining and quarrying      Primary  \
# 0                           14819416              1484300     16303716
# 1                             686117                30842       716959
# 2                            3855548              1471149      5326697
# 3                            7951890                68107      8019997
# 4                              16233                  179        16412
# 5                            3948847              2451970      6400817
# 6                             250568               963777      1214345
# 7                             308507                 3622       312129
# 8                          1.377e+07          2.11722e+06  1.58872e+07
# 9                        8.01524e+06                25186  8.04042e+06
# 10                           1514981                33385      1548366
# 11                           3211065              2037289      5248354
# ...

# %%
#Converting the 'State' column as First Column:
cols = df_new.columns.tolist()
cols
cols = cols[-1:] + cols[:-1]
cols
df_new = df_new[cols] 
df_new
# Out:
#                 State Agriculture, forestry and fishing Mining and quarrying  \
# 0      Andhra_Pradesh                          14819416              1484300
# 1   Arunachal_Pradesh                            686117                30842
# 2               Assam                           3855548              1471149
# 3               Bihar                           7951890                68107
# 4          Chandigarh                             16233                  179
# 5        Chhattisgarh                           3948847              2451970
# 6               Delhi                            250568               963777
# 7                 Goa                            308507                 3622
# 8             Gujarat                         1.377e+07          2.11722e+06
# 9             Haryana                       8.01524e+06                25186
# 10   Himachal_Pradesh                           1514981                33385
# ...

# %% [markdown]
# ### Filter out the union territories (Delhi, Chandigarh, Andaman and Nicobar Islands, etc.) for further analysis, as they are governed directly by the central, not state governments.

# %%
ut = df_new[df_new['State'] == 'Chandigarh'].index
ut1= df_new[df_new['State']=='Delhi'].index
ut2=df_new[df_new['State']=='Puducherry'].index
# Delete these row indexes from dataFrame
df_new=df_new.drop(ut )
df_new=df_new.drop(ut1 )
df_new=df_new.drop(ut2 )
df_new
# Out:
#                 State Agriculture, forestry and fishing Mining and quarrying  \
# 0      Andhra_Pradesh                          14819416              1484300
# 1   Arunachal_Pradesh                            686117                30842
# 2               Assam                           3855548              1471149
# 3               Bihar                           7951890                68107
# 5        Chhattisgarh                           3948847              2451970
# 7                 Goa                            308507                 3622
# 8             Gujarat                         1.377e+07          2.11722e+06
# 9             Haryana                       8.01524e+06                25186
# 10   Himachal_Pradesh                           1514981                33385
# 11          Jharkhand                           3211065              2037289
# 12          Karnataka                          11219422               846882
# ...

# %% [markdown]
# ### Plot the GDP per capita for all the states.

# %% [markdown]
# #### Q. Identify the top 5 and the bottom 5 states based on the GDP per capita.

# %%
df_new.sort_values(by='Per Capita GSDP (Rs.)').plot(x='State', y='Per Capita GSDP (Rs.)',kind='bar',figsize=(10, 10))
plt.title("GDP Per-Capita of All States")
plt.show()

# %% [markdown]
# ##### ANSWER:
# As per the bar graph plotted above:
# Top 5 states based on GDP per capita are:
# Goa, Sikkim, Haryana,Kerala,Uttarakhand
# Bottom 5 states based on GDP per capita are:
# Bihar,Uttar_pradesh, Manipur,Assam, Jharkand

# %% [markdown]
# #### Q. Find the ratio of the highest per capita GDP to the lowest per capita GDP.

# %% [markdown]
# ##### State with highest per capita GDP is GOA
# ##### State with lowest per capita GDP is BIHAR

# %%
#ratio of the highest per capita GDP to the lowest per capita GDP.
ax=df_new[['Per Capita GSDP (Rs.)','State']].sort_values(by='Per Capita GSDP (Rs.)')
ax
ratio=ax['Per Capita GSDP (Rs.)'][7]/ax['Per Capita GSDP (Rs.)'][3]
print('Ratio:',ratio)
# Out:
# Ratio: 8.004741709371503

# %% [markdown]
# ### Plot the percentage contribution of the primary, secondary and tertiary sectors as a percentage of the total GDP for all the states.

# %%
#Calculating the percentage contribution of each sector and adding a new column for each sector.
df_new['Primary_contribution']=100*(df_new['Primary']/df_new['Gross State Domestic Product'])
df_new['Secondary_contribution']=100*(df_new['Secondary']/df_new['Gross State Domestic Product'])
df_new['Tertiary_contribution']=100*(df_new['Tertiary']/df_new['Gross State Domestic Product'])
df_new
# Out:
#                 State Agriculture, forestry and fishing Mining and quarrying  \
# 0      Andhra_Pradesh                          14819416              1484300
# 1   Arunachal_Pradesh                            686117                30842
# 2               Assam                           3855548              1471149
# 3               Bihar                           7951890                68107
# 5        Chhattisgarh                           3948847              2451970
# 7                 Goa                            308507                 3622
# 8             Gujarat                         1.377e+07          2.11722e+06
# 9             Haryana                       8.01524e+06                25186
# 10   Himachal_Pradesh                           1514981                33385
# 11          Jharkhand                           3211065              2037289
# 12          Karnataka                          11219422               846882
# ...

# %% [markdown]
# #### Q. Which plot will you use here? Why?

# %% [markdown]
#  ##### ANSWER:
#  A Bar Chart with multiple bars for each sector is used for plotting various sectors percentage contribution.

# %%
#ploting percentage contro of sectors: using Bar Graph:
df_new.reset_index().plot(x='State', y=['Primary_contribution','Secondary_contribution','Tertiary_contribution'],kind='bar',figsize=(15,10))
plt.title("PERCENTAGE CONTRIBUTION OF EACH SECTOR")
plt.ylabel("Perctage contribution")
plt.show()

# %% [markdown]
# #### Q. Why is (Primary + Secondary + Tertiary) not equal to total GDP?

# %%
df_new['(Primary+Secondary+Tertiary)']=df_new['Primary']+df_new['Secondary']+df_new['Tertiary']
df_new
# Out:
#                 State Agriculture, forestry and fishing Mining and quarrying  \
# 0      Andhra_Pradesh                          14819416              1484300
# 1   Arunachal_Pradesh                            686117                30842
# 2               Assam                           3855548              1471149
# 3               Bihar                           7951890                68107
# 5        Chhattisgarh                           3948847              2451970
# 7                 Goa                            308507                 3622
# 8             Gujarat                         1.377e+07          2.11722e+06
# 9             Haryana                       8.01524e+06                25186
# 10   Himachal_Pradesh                           1514981                33385
# 11          Jharkhand                           3211065              2037289
# 12          Karnataka                          11219422               846882
# ...

# %% [markdown]
# ##### ANSWER:
# Adding a new column to calculate(Primary + Secondary + Tertiary).
# The total GDP is not equal to (Primary + Secondary + Tertiary) because Total GDP contains  total of all the sectors as well as the taxes paid by the population .
# Also the subsidies that are given by the Government of India are excluded from the total GDP.

# %% [markdown]
# #### Q. Can you draw any insight from this? Find correlation of percentile of the state (% of states with lower per capita GDP) and %contribution of Primary sector to total GDP.

# %%
#Creating a new column named 'Percentile' to calulate the percentile rank based on the GSDP values.
df_new['Percentile']=df_new['Gross State Domestic Product'].rank(pct=True)
df_new
# Out:
#                 State Agriculture, forestry and fishing Mining and quarrying  \
# 0      Andhra_Pradesh                          14819416              1484300
# 1   Arunachal_Pradesh                            686117                30842
# 2               Assam                           3855548              1471149
# 3               Bihar                           7951890                68107
# 5        Chhattisgarh                           3948847              2451970
# 7                 Goa                            308507                 3622
# 8             Gujarat                         1.377e+07          2.11722e+06
# 9             Haryana                       8.01524e+06                25186
# 10   Himachal_Pradesh                           1514981                33385
# 11          Jharkhand                           3211065              2037289
# 12          Karnataka                          11219422               846882
# ...

# %%
#Changing the datatype from Object to Float for all the columns except the 'State' column. 
#This is required to calculate the correlation value.
cols=df_new.columns
cols
for i in range(1,len(cols)):
    df_new[cols[i]]=df_new[cols[i]].apply(pd.to_numeric)
    
df_new.dtypes
# Out:
# State                                                                    object
# Agriculture, forestry and fishing                                       float64
# Mining and quarrying                                                    float64
# Primary                                                                 float64
# Manufacturing                                                           float64
# Electricity, gas, water supply & other utility services                 float64
# Construction                                                            float64
# Secondary                                                               float64
# Trade, repair, hotels and restaurants                                   float64
# Transport, storage, communication & services related to broadcasting    float64
# Financial services                                                      float64
# Real estate, ownership of dwelling & professional services              float64
# ...

# %%
#Correlation between Primary contribution and Percentile of States:
#Heatmap is used for determing the correlation.
data=df_new[['Primary_contribution','Percentile']]
corre=data.corr(method='pearson')
ax=sns.heatmap(corre)

# %%
#Using a Regplot
sns.regplot(x='Primary_contribution', y='Percentile', data=df_new)
plt.title('Correlation of percentile rank and contribution of Primary sector')
plt.show()

# %% [markdown]
# ##### ANSWER:
# From the above Regplot we can conclude that the Percentile Rank of most of the States is stable and has a quite stable contribution with the Primary Sectors.

# %% [markdown]
# ### Categorise the states into four groups based on the GDP per capita (C1, C2, C3, C4, where C1 would have the highest per capita GDP and C4, the lowest). The quantile values are (0.20,0.5, 0.85, 1), i.e., the states lying between the 85th and the 100th percentile are in C1; those between the 50th and the 85th percentiles are in C2, and so on.

# %%
#calculation the quantile values:
df_new['Per Capita GSDP (Rs.)'].quantile([0.2,0.5,0.85,1])
# Out:
# 0.20     65187.0
# 0.50    104977.0
# 0.85    153246.2
# 1.00    271793.0
# Name: Per Capita GSDP (Rs.), dtype: float64

# %%
#Creating a new column called 'Category' that will tag each state with the particular category based on the conditions:
df_new.loc[(df_new['Per Capita GSDP (Rs.)']>=153246.2) & (df_new['Per Capita GSDP (Rs.)']<=271793.0), 'Category'] = 'C1'    
    
df_new.loc[(df_new['Per Capita GSDP (Rs.)']>=104977.0) & (df_new['Per Capita GSDP (Rs.)']<153246.2), 'Category'] = 'C2'

df_new.loc[(df_new['Per Capita GSDP (Rs.)']>=65187.0) & (df_new['Per Capita GSDP (Rs.)']<104977.0), 'Category'] = 'C3'

df_new.loc[(df_new['Per Capita GSDP (Rs.)']<65187.0), 'Category'] = 'C4'

df_new
# Out:
#                 State  Agriculture, forestry and fishing  \
# 0      Andhra_Pradesh                         14819416.0
# 1   Arunachal_Pradesh                           686117.0
# 2               Assam                          3855548.0
# 3               Bihar                          7951890.0
# 5        Chhattisgarh                          3948847.0
# 7                 Goa                           308507.0
# 8             Gujarat                         13769969.0
# 9             Haryana                          8015238.0
# 10   Himachal_Pradesh                          1514981.0
# 11          Jharkhand                          3211065.0
# 12          Karnataka                         11219422.0
# 13             Kerala                          5930617.0
# 14     Madhya_Pradesh                         16235647.0
# 15        Maharashtra                         16475655.0
# 16            Manipur                           383140.0
# ...

# %%
#grouping by category
data=df_new[['State','Category']]  #filtering the data
data
data=data.groupby('Category') 
c1=data.get_group('C1')
c2=data.get_group('C2')
c3=data.get_group('C3')
c4=data.get_group('C4')
print(c1)
print(c2)
print(c3)
print(c4)
# Out:
#       State Category
# 7       Goa       C1
# 9   Haryana       C1
# 13   Kerala       C1
# 24   Sikkim       C1
#                 State Category
# 0      Andhra_Pradesh       C2
# 1   Arunachal_Pradesh       C2
# 8             Gujarat       C2
# 10   Himachal_Pradesh       C2
# 12          Karnataka       C2
# 15        Maharashtra       C2
# 22             Punjab       C2
# 25         Tamil_Nadu       C2
# 26          Telangana       C2
# 28        Uttarakhand       C2
#            State Category
# 5   Chhattisgarh       C3
# 17     Meghalaya       C3
# 18       Mizoram       C3
# 19      Nagaland       C3
# 20        Odisha       C3
# 23     Rajasthan       C3
# 27       Tripura       C3
#              State Category
# 2            Assam       C4
# 3            Bihar       C4
# 11       Jharkhand       C4
# 14  Madhya_Pradesh       C4
# 16         Manipur       C4
# 29   Uttar_Pradesh       C4

# %%
#grouping data based on Category:
data1=df_new[['State','Category','Agriculture, forestry and fishing','Mining and quarrying','Manufacturing',
'Electricity, gas, water supply & other utility services','Construction','Trade, repair, hotels and restaurants',
'Transport, storage, communication & services related to broadcasting','Financial services',
'Real estate, ownership of dwelling & professional services','Public administration','Other services',
'Gross State Domestic Product','Per Capita GSDP (Rs.)']]  #filtering the data
data1=data1.groupby('Category').sum()

data1
# Out:
#           Agriculture, forestry and fishing  Mining and quarrying  \
# Category
# C1                               14391809.0              588961.0
# C2                               90028438.0            11857646.0
# C3                               27407472.0             9351471.0
# C4                               56735044.0             6096419.0
#
#           Manufacturing  \
# Category
# C1           13758793.0
# C2          113868796.0
# C3           17366065.0
# C4           24987032.0
#
#           Electricity, gas, water supply & other utility services  \
# Category
# C1                                                2000998.0
# C2                                               14975107.0
# C3                                                3453045.0
# C4                                                4310264.0
#
#           Construction  Trade, repair, hotels and restaurants  \
# Category
# C1          11264451.0                             13995159.0
# ...

# %% [markdown]
# ### For each category (C1, C2, C3, C4):
# ### Find the top 3/4/5 sub-sectors (such as agriculture, forestry and fishing, crops, manufacturing etc., not primary, secondary and tertiary) that contribute to approximately 80% of the GSDP of each category.

# %%
#Finding the percentage contribution of each sub-sector:
#A new column is added for each sector:
data1['Agriculture, forestry and fishing_contribution']=100*(data1['Agriculture, forestry and fishing']/data1['Gross State Domestic Product'])
data1['Mining and quarrying_contribution']=100*(data1['Mining and quarrying']/data1['Gross State Domestic Product'])
data1['Manufacturing_contribution']=100*(data1['Manufacturing']/data1['Gross State Domestic Product'])
data1['Electricity_contribution']=100*(data1['Electricity, gas, water supply & other utility services']/data1['Gross State Domestic Product'])
data1['Construction_contribution']=100*(data1['Construction']/data1['Gross State Domestic Product'])
data1['Trade_contribution']=100*(data1['Trade, repair, hotels and restaurants']/data1['Gross State Domestic Product'])
data1['Transport_contribution']=100*(data1['Transport, storage, communication & services related to broadcasting']/data1['Gross State Domestic Product'])
data1['Financial services_contribution']=100*(data1['Financial services']/data1['Gross State Domestic Product'])
data1['Real estate_contribution']=100*(data1['Real estate, ownership of dwelling & professional services']/data1['Gross State Domestic Product'])
data1['Public administration_contribution']=100*(data1['Public administration']/data1['Gross State Domestic Product'])
data1['Other services_contribution']=100*(data1['Other services']/data1['Gross State Domestic Product'])
data1
# Out:
#           Agriculture, forestry and fishing  Mining and quarrying  \
# Category
# C1                               14391809.0              588961.0
# C2                               90028438.0            11857646.0
# C3                               27407472.0             9351471.0
# C4                               56735044.0             6096419.0
#
#           Manufacturing  \
# Category
# C1           13758793.0
# C2          113868796.0
# C3           17366065.0
# C4           24987032.0
#
#           Electricity, gas, water supply & other utility services  \
# Category
# C1                                                2000998.0
# C2                                               14975107.0
# C3                                                3453045.0
# C4                                                4310264.0
#
#           Construction  Trade, repair, hotels and restaurants  \
# Category
# C1          11264451.0                             13995159.0
# ...

# %%
#plotting contribution of sub-sectors:
plt.subplot(2,2,1)
c1_data=data1.loc['C1','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c1_data.plot(kind='bar',figsize=(9,8),color='g')
plt.title('C1')
plt.subplot(2,2,2)
c2_data=data1.loc['C2','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c2_data.plot(kind='bar',figsize=(9,8),color='r')
plt.title('C2')
plt.subplot(2,2,3)
c3_data=data1.loc['C3','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c3_data.plot(kind='bar',figsize=(9,8),color='b')
plt.title('C3')
plt.subplot(2,2,4)
c4_data=data1.loc['C4','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c4_data.plot(kind='bar',figsize=(9,8),color='m')
plt.title('C4')
# Out:
# Text(0.5, 1.0, 'C4')

# %% [markdown]
# #### Finding the top 3/4/5 sub-sectors that contribute upto 80% of total GDP for all the 4 categories.
# #### Q. Plot the contribution of the sub-sectors as a percentage of the GSDP of each category

# %%
#Filtering the data with each category and the sector contributions.
#Calcuating the Cumulative Sum in a new column 'Cum_Sum' upto 80 using the cumsum() function.
#Plotting the sector  for which the contribution is upto 80%

# %%
#FOR C1 Category:
c1_data=data1.loc['C1','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c1=c1_data.to_frame() #converting series to a dataframe
c1['Cum_Sum']=c1.cumsum()
c1=c1.loc[c1['Cum_Sum']<=80]
c1.columns=['%_contro','upto_80']
c1.reset_index()
c1.sort_values(by='%_contro',ascending=False).plot(y='%_contro',kind='bar', figsize=(8,6),color='c')
plt.title('Sectors that contribute 80% of total GDP')
plt.show()

# %%
#FOR C2 Category:
c2_data=data1.loc['C2','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c2=c2_data.to_frame()
c2['Cum_Sum']=c2.cumsum()
c2=c2.loc[c2['Cum_Sum']<=80]
c2.columns=['%_contro','upto_80']
c2.reset_index()
c2.sort_values(by='%_contro',ascending=False).plot(y='%_contro',kind='bar', figsize=(8,6),color='k')
plt.title('Sectors that contribute 80% of total GDP')
plt.show()

# %%
#FOR C3 Category:
c3_data=data1.loc['C3','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c3=c3_data.to_frame()
c3['Cum_Sum']=c3.cumsum()
c3=c3.loc[c3['Cum_Sum']<=80]
c3.columns=['%_contro','upto_80']
c3.reset_index()
c3.sort_values(by='%_contro',ascending=False).plot(y='%_contro',kind='bar', figsize=(8,6),color='r')
plt.title('Sectors that contribute 80% of total GDP')
plt.show()

# %%
#FOR C4 Category:
c4_data=data1.loc['C4','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c4=c3_data.to_frame()
c4['Cum_Sum']=c4.cumsum()
c4=c4.loc[c4['Cum_Sum']<=80]
c4.columns=['%_contro','upto_80']
c4.reset_index()
c4.sort_values(by='%_contro',ascending=False).plot(y='%_contro',kind='bar', figsize=(8,6),color='g')
plt.title('Sectors that contribute 80% of total GDP')
plt.show()

# %% [markdown]
# #### Q.How does the GDP distribution of the top states (C1) differ from the others?

# %%
#plotting the GSDP across all categories:
data1.reset_index().plot(x='Category',y='Gross State Domestic Product',kind='bar')
plt.show()

# %% [markdown]
# ##### ANSWER:
# After comparing the categories, we can say that GSDP of C2, C4 are approximately 2 to 3 times larger than C1 or  GSDp of C1 is clos to GSdp of C3

# %% [markdown]
# #### Q.Which sub-sectors seem to be correlated with high GDP?

# %% [markdown]
# From the above graphs, subsectors that are correlated with high GDP are:
# Agriculture,forestry, fishing ,
# Manufacturing  and Real estate.

# %% [markdown]
# #### Q.Which sub-sectors do the various categories need to focus on?

# %%
#Filtering the data with various sectors and their contribution.
#Sorting the values in descending order.
#extracting the last values from the data frame to get the sectors that has lss contribution.

# %%
c1_sectors=data1.loc['C1','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c1=c1_sectors.to_frame()
c1=c1.sort_values(by='C1',ascending=False)
list(c1.tail().index)
# Out:
# ['Transport_contribution',
#  'Financial services_contribution',
#  'Public administration_contribution',
#  'Electricity_contribution',
#  'Mining and quarrying_contribution']

# %%
c2_sectors=data1.loc['C2','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c2=c2_sectors.to_frame()
c2=c2.sort_values(by='C2',ascending=False)
list(c2.tail().index)
# Out:
# ['Transport_contribution',
#  'Financial services_contribution',
#  'Public administration_contribution',
#  'Electricity_contribution',
#  'Mining and quarrying_contribution']

# %%
c3_sectors=data1.loc['C3','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c3=c3_sectors.to_frame()
c3=c3.sort_values(by='C3',ascending=False)
list(c3.tail().index)
# Out:
# ['Other services_contribution',
#  'Transport_contribution',
#  'Public administration_contribution',
#  'Financial services_contribution',
#  'Electricity_contribution']

# %%
c4_sectors=data1.loc['C4','Agriculture, forestry and fishing_contribution':'Other services_contribution']
c4=c4_sectors.to_frame()
c4=c4.sort_values(by='C4',ascending=False)
list(c4.tail().index)
# Out:
# ['Other services_contribution',
#  'Public administration_contribution',
#  'Financial services_contribution',
#  'Mining and quarrying_contribution',
#  'Electricity_contribution']

# %% [markdown]
# #### Q.Finally, provide at least two recommendations for each category to improve the per capita GDP.

# %% [markdown]
# ###### Recommendation no.1:
# The sub-sectors that are contributing less should be focused more.
# Analysis can be made for why these sectors are less contributing.
# The reason can be loss in those sectors.

# %% [markdown]
# ##### Recommendation no.2:
# The sectors that are contributing more should not be neglected.
# Instead those sectors should be worked on more for more profit and thus increasing the Total GDP.

# %% [markdown]
# # Part-II: GDP and Education Dropout Rates

# %% [markdown]
# ##### Merging dropout_data and Data-1B

# %%
#Reading Drop-out dataset:
dropout_df=pd.read_csv(r'..\Final_GDP\rs_session243_au570_1.1.csv')
dropout_df
# Out:
#       Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0           1              A & N Islands                 0.68
# 1           2             Andhra Pradesh                 3.18
# 2           3          Arunachal Pradesh                15.16
# 3           4                      Assam                 6.24
# 4           5                      Bihar                  NaN
# 5           6                 Chandigarh                  NaN
# 6           7                Chhatisgarh                 4.14
# 7           8       Dadra & Nagar Haveli                  NaN
# 8           9                Daman & Diu                  NaN
# 9          10                      Delhi                  NaN
# 10         11                        Goa                  NaN
# 11         12                    Gujarat                 0.74
# 12         13                    Haryana                 1.29
# 13         14           Himachal Pradesh                 0.45
# ...

# %%
#Renaming the columns of dropout dataset:
dropout_df = dropout_df.rename(columns = {'Primary - 2014-2015':'Primary - 2013-2014','Primary - 2014-2015.1':'Primary - 2014-2015'})

# %%
#Extracting the required columns from drop-out dataset:
#Level of Education, Primary-2014-2015,UpperPrimary-2014-15 and Secondary-2014-15
#we only require data for the year 2014-15.
dropout_df=dropout_df[['Level of Education - State','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]

# %% [markdown]
# ###### Cleaning the drop-out dataset.

# %%
#dropping the rows if there are any NAN values:
dropout_df=dropout_df.dropna(how='any')

#Renaming the columns as per the column names in DATA-1B.
#This is required for merging the 2 data sets.
dropout_df=dropout_df.rename(columns={'Level of Education - State':'State'}) #this is the common column in both the datasets hence renaming it to 'STATE'.
dropout_df=dropout_df.replace(['Andhra Pradesh'],['Andhra_Pradesh'])
dropout_df=dropout_df.replace(['Arunachal Pradesh'],['Arunachal_Pradesh'])
dropout_df=dropout_df.replace(['Chhatisgarh'],['Chhattisgarh'])
dropout_df=dropout_df.replace(['Himachal Pradesh'],['Himachal_Pradesh'])
dropout_df=dropout_df.replace(['Madhya Pradesh'],['Madhya_Pradesh'])
dropout_df=dropout_df.replace(['Tamil Nadu'],['Tamil_Nadu'])
dropout_df=dropout_df.replace(['Uttar Pradesh'],['Uttar_Pradesh'])
dropout_df=dropout_df.replace(['Uttrakhand'],['Uttarakhand'])

dropout_df
# Out:
#                    State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0          A & N Islands                 0.51                       1.69
# 1         Andhra_Pradesh                 6.72                       5.20
# 2      Arunachal_Pradesh                10.82                       6.71
# 3                  Assam                15.36                      10.51
# 6           Chhattisgarh                 2.91                       5.85
# 7   Dadra & Nagar Haveli                 1.47                       4.02
# 8            Daman & Diu                 1.11                       3.11
# 10                   Goa                 0.73                       0.07
# 11               Gujarat                 0.89                       6.41
# 12               Haryana                 5.61                       5.81
# 13      Himachal_Pradesh                 0.64                       0.87
# 14     Jammu and Kashmir                 6.79                       5.44
# ...

# %%
#Merging the dropout-data with sector wise data(DATA-1B):

final_df=pd.merge(df_new,dropout_df,how='inner',on='State')
#Renaming the Population column for convenience.
final_df=final_df.rename(columns = {list(final_df)[19]:'Population'}) 
final_df.columns
# Out:
# Index(['State', 'Agriculture, forestry and fishing', 'Mining and quarrying',
#        'Primary', 'Manufacturing',
#        'Electricity, gas, water supply & other utility services',
#        'Construction', 'Secondary', 'Trade, repair, hotels and restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Financial services',
#        'Real estate, ownership of dwelling & professional services',
#        'Public administration', 'Other services', 'Tertiary',
#        'TOTAL GSVA at basic prices', 'Taxes on Products',
#        'Subsidies on products', 'Gross State Domestic Product', 'Population',
#        'Per Capita GSDP (Rs.)', 'Primary_contribution',
#        'Secondary_contribution', 'Tertiary_contribution',
#        '(Primary+Secondary+Tertiary)', 'Percentile', 'Category',
#        'Primary - 2014-2015', 'Upper Primary - 2014-2015',
#        'Secondary - 2014-2015'],
#       dtype='object')

# %% [markdown]
# ### Analyse if there is any correlation of GDP per capita with dropout rates in education (primary, upper primary and secondary) for the year 2014-2015 for each state. Choose an appropriate plot to conduct this analysis.

# %%
#correlation with dropout_rate with the per capita gsdp:
plt.figure(figsize=(14,12))
final_df.plot(x='Per Capita GSDP (Rs.)',y='Primary - 2014-2015',kind='scatter')
plt.show()
final_df.plot(x='Per Capita GSDP (Rs.)',y='Upper Primary - 2014-2015',kind='scatter',color='g')
plt.show()
final_df.plot(x='Per Capita GSDP (Rs.)',y='Secondary - 2014-2015',kind='scatter',color='r')
plt.show()

# %% [markdown]
# #### Scatter plot is used for plotting the GDP per capita with the drop out rates.
# #### ANALYSIS: The above scatter plots shows that the GDP per capita is increasing and the drop-out rates are decreasing gradually.

# %% [markdown]
# #### Q.Is there any correlation between dropout rate and %contribution of each sector (Primary, Secondary and Tertiary) to the total GDP?

# %%
#correlation of dropout rate with sectors contribution:
fig=plt.figure(figsize=(10,10))
dropout_corr=final_df[['Primary_contribution','Secondary_contribution','Tertiary_contribution','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]
corre=dropout_corr.corr(method='pearson')
ax=sns.heatmap(corre)

# %% [markdown]
# #### Heatmap is used to find the Correlation between the Drop-out rates and the Sector wise contribution.

# %% [markdown]
# ### You have the total population of each state from the data in part I. Is there any correlation between dropout rates and population? What is the expected trend and what is the observation?

# %%
#Correlation of total population with the drop-out rates:
fig=plt.figure(figsize=(10,10))
dropout_corr=final_df[['Population','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]
corre=dropout_corr.corr(method='pearson')
ax=sns.heatmap(corre)

# %% [markdown]
# ### Write down the key insights you draw from this data:
#
# #### Form at least one reasonable hypothesis for the observations from the data

# %% [markdown]
# ##### Hypothesis 1:
# As the GSDP increases , the drop-out rates decreases gradually.
# ##### Hypothesis 2:
# The Primary and Secondary sectors have a great impact on the drop-out rates of Secondary 2014-15.
